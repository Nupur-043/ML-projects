# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## ML PROJECT

# %%
import seaborn as sns
# %matplotlib inline

# %%
housing = pd.read_csv('housing.csv')

# %%
housing.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
data1=housing.copy()

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder=LabelEncoder()
data1['new_ocean_proximity']=label_encoder.fit_transform(housing['ocean_proximity'])
data1
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
data1.drop('ocean_proximity',inplace=True,axis=1)
data1
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %% [markdown]
# ### Splitting
#     to prevent data leakage

# %%
target = 'median_house_value'

# %%
y = data1[target]
X = data1.drop(target,axis=1)

# %%
X.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  new_ocean_proximity
# 0       322.0       126.0         8.3252                    3
# 1      2401.0      1138.0         8.3014                    3
# 2       496.0       177.0         7.2574                    3
# 3       558.0       219.0         5.6431                    3
# 4       565.0       259.0         3.8462                    3

# %%
y.head()
# Out:
# 0    452600.0
# 1    358500.0
# 2    352100.0
# 3    341300.0
# 4    342200.0
# Name: median_house_value, dtype: float64

# %%
def train_test_split(X,y, test_ratio=0.2,random_state=123):
    np.random.seed(random_state)
    size = X.shape[0]
    test_size= int(size * test_ratio)
    train_size = size - test_size
    indexes = np.arange(size)
    np.random.shuffle(indexes)
#     if show_output:
#         print('Total: ',size)
#         print('Train: ',train_size)
#         print("Test: ", test_size)    
        
    train_idx = indexes[:train_size]
    test_idx = indexes[train_size:]
    train_X = X.iloc[train_idx]
    test_X = X.iloc[test_idx]
    if y is not None:
        train_y = y.iloc[train_idx]
        test_y = y.iloc[test_idx]
        return train_X,test_X, train_y, test_y
    
    
    return train_X, test_X

# %%
X_train, X_test, y_train,y_test = train_test_split(X,y,test_ratio=0.2)

# %%
X_train.head()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 19121    -122.64     38.24                40.0       1974.0           410.0
# 20019    -119.05     36.09                 9.0       3297.0           568.0
# 15104    -116.98     32.85                12.0       3570.0           713.0
# 3720     -118.42     34.20                27.0       3201.0           970.0
# 8938     -118.47     34.01                41.0       2704.0           557.0
#
#        population  households  median_income  new_ocean_proximity
# 19121      1039.0       398.0         3.7917                    0
# 20019      1749.0       568.0         4.0217                    1
# 15104      3321.0       666.0         4.0882                    0
# 3720       3403.0       948.0         2.2377                    0
# 8938       1047.0       478.0         4.4211                    0

# %%
X_train.shape
# Out:
# (16512, 9)

# %%
X_test.head()
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 3736    -118.40     34.18                32.0       3724.0           899.0
# 2231    -119.78     36.84                 7.0       4907.0          1075.0
# 6111    -117.90     34.13                25.0       3076.0           856.0
# 6946    -118.08     33.99                38.0       1683.0           328.0
# 5368    -118.40     34.05                43.0       1028.0           145.0
#
#       population  households  median_income  new_ocean_proximity
# 3736      1912.0       791.0         3.5711                    0
# 2231      2014.0       909.0         3.2147                    1
# 6111      2868.0       752.0         2.6619                    0
# 6946      1369.0       339.0         3.6196                    0
# 5368       394.0       149.0        10.4519                    0

# %%
X_test.shape
# Out:
# (4128, 9)

# %%
(X['new_ocean_proximity'].value_counts()/ X.shape[0])*100
# Out:
# 0    44.263566
# 1    31.739341
# 4    12.877907
# 3    11.094961
# 2     0.024225
# Name: new_ocean_proximity, dtype: float64

# %%
(X_train['new_ocean_proximity'].value_counts()/ X_train.shape[0])*100
# Out:
# 0    44.295058
# 1    31.801114
# 4    12.645349
# 3    11.234254
# 2     0.024225
# Name: new_ocean_proximity, dtype: float64

# %%
(X_test['new_ocean_proximity'].value_counts()/ X_test.shape[0])*100
# Out:
# 0    44.137597
# 1    31.492248
# 4    13.808140
# 3    10.537791
# 2     0.024225
# Name: new_ocean_proximity, dtype: float64

# %%
from sklearn.model_selection import train_test_split
# Random split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=123)

# %%
X_train.shape
# Out:
# (16512, 9)

# %%
X_train.head()
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 9950    -122.33     38.38                28.0       1020.0           169.0
# 3547    -118.60     34.26                18.0       6154.0          1070.0
# 4448    -118.21     34.07                47.0       1346.0           383.0
# 6984    -118.02     33.96                36.0       2071.0           398.0
# 4432    -118.20     34.08                49.0       1320.0           309.0
#
#       population  households  median_income  new_ocean_proximity
# 9950       504.0       164.0         4.5694                    1
# 3547      3010.0      1034.0         5.6392                    0
# 4448      1452.0       371.0         1.7292                    0
# 6984       988.0       404.0         4.6226                    0
# 4432      1405.0       328.0         2.4375                    0

# %%
(X_train['new_ocean_proximity'].value_counts()/ X_train.shape[0])*100
# Out:
# 0    44.385901
# 1    31.679990
# 4    12.857316
# 3    11.046512
# 2     0.030281
# Name: new_ocean_proximity, dtype: float64

# %%
(X_test['new_ocean_proximity'].value_counts()/ X_test.shape[0])*100
# Out:
# 0    43.774225
# 1    31.976744
# 4    12.960271
# 3    11.288760
# Name: new_ocean_proximity, dtype: float64

# %%
X_train
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 9950     -122.33     38.38                28.0       1020.0           169.0
# 3547     -118.60     34.26                18.0       6154.0          1070.0
# 4448     -118.21     34.07                47.0       1346.0           383.0
# 6984     -118.02     33.96                36.0       2071.0           398.0
# 4432     -118.20     34.08                49.0       1320.0           309.0
# ...          ...       ...                 ...          ...             ...
# 7763     -118.10     33.91                36.0        726.0             NaN
# 15377    -117.24     33.37                14.0       4687.0           793.0
# 17730    -121.76     37.33                 5.0       4153.0           719.0
# 15725    -122.44     37.78                44.0       1545.0           334.0
# 19966    -119.08     36.21                20.0       1911.0           389.0
#
# ...

# %%
plt.figure(dpi=100)
sns.scatterplot(x='longitude',y='latitude', data=X_train, hue='new_ocean_proximity')

plt.show()

# %%
plt.figure(dpi=100)
sns.scatterplot(x='longitude',y='latitude', data=housing, size='median_house_value', alpha=0.7)

plt.show()

# %%
plt.figure(dpi=100)
sns.scatterplot(x='longitude',y='latitude', data=housing, size='median_house_value', alpha=0.2
                ,palette='rainbow', hue='ocean_proximity')

plt.show()

# %%
housing.groupby('ocean_proximity')[['median_house_value']].count().sort_values(ascending=False,
                                                                              by='median_house_value')
# Out:
#                  median_house_value
# ocean_proximity
# <1H OCEAN                      9136
# INLAND                         6551
# NEAR OCEAN                     2658
# NEAR BAY                       2290
# ISLAND                            5

# %%
housing.groupby('ocean_proximity').agg({'median_house_value':'mean'}).sort_values(ascending=False,
                                                                                 by='median_house_value')
# Out:
#                  median_house_value
# ocean_proximity
# ISLAND                380440.000000
# NEAR BAY              259212.311790
# NEAR OCEAN            249433.977427
# <1H OCEAN             240084.285464
# INLAND                124805.392001

# %%
plt.figure(dpi=100)
sns.scatterplot(x='total_rooms',y='total_bedrooms', data=housing,palette='rainbow',hue='median_house_value')

plt.show()

# %%
corr = X_train.corrwith(y_train).sort_values(ascending=False)

corr
# Out:
# median_income          0.688904
# total_rooms            0.132965
# housing_median_age     0.099487
# new_ocean_proximity    0.078337
# households             0.064043
# total_bedrooms         0.048823
# population            -0.024484
# longitude             -0.038349
# latitude              -0.150574
# dtype: float64

# %%
for column in X_train:
    plt.figure(dpi=100)
    plt.title(f'{column} vs Price')
    plt.scatter(X_train[column],y_train,marker='.',label=f"r={corr[column]:.2f}")
    plt.xlabel(column)
    plt.ylabel('Median House Value')
    plt.legend()
    plt.grid()
    plt.tight_layout()
    plt.show()

# %%
long_lat=X_train['longitude'] + X_train['latitude']

# %%
np.corrcoef(long_lat, y_train)[0,1]
# Out:
# -0.4897306978304824

# %%
plt.scatter(long_lat,y_train)
plt.show()

# %% [markdown]
#     We know through analysis that median_income is the most important feature.

# %%
housing['median_income'].describe()
# Out:
# count    20640.000000
# mean         3.870671
# std          1.899822
# min          0.499900
# 25%          2.563400
# 50%          3.534800
# 75%          4.743250
# max         15.000100
# Name: median_income, dtype: float64

# %%
plt.hist(housing['median_income'],bins=100,ec='k')
plt.show()

# %%
data1['income_cat']=pd.cut(data1['median_income'],bins=[0, 2, 4, 6 , 8,np.inf]
      , labels=['very low','low','avg','high','very high'])

# %%
data1.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value  \
# 0       322.0       126.0         8.3252            452600.0
# 1      2401.0      1138.0         8.3014            358500.0
# 2       496.0       177.0         7.2574            352100.0
# 3       558.0       219.0         5.6431            341300.0
# 4       565.0       259.0         3.8462            342200.0
#
#    new_ocean_proximity income_cat
# 0                    3  very high
# 1                    3  very high
# 2                    3       high
# ...

# %%
data1['income_cat'].value_counts()
# Out:
# low          10096
# avg           5725
# very low      2457
# high          1672
# very high      690
# Name: income_cat, dtype: int64

# %%
plt.figure(dpi=100)
data1['income_cat'].value_counts().plot(kind='bar', color=['r','g','b','y','c'])
plt.show()

# %%
(data1['income_cat'].value_counts()/data1.shape[0])*100
# Out:
# low          48.914729
# avg          27.737403
# very low     11.904070
# high          8.100775
# very high     3.343023
# Name: income_cat, dtype: float64

# %%
plt.figure(dpi=100)
colors=['gold','yellowgreen','lightcoral','lightskyblue','lightgray']
((data1['income_cat'].value_counts()/data1.shape[0])*100).plot(kind='pie',
                                                              colors=colors,
                                                               autopct='%.2f%%')
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
X['income_cat']=pd.cut(X['median_income'],bins=[0, 2, 4, 6 , 8,np.inf]
      , labels = [1,2,3,4,5])
print((X['income_cat'].value_counts()/X.shape[0])*100)
plt.figure(dpi=100)
colors=['gold','yellowgreen','lightcoral','lightskyblue','lightgray']
((X['income_cat'].value_counts()/X.shape[0])*100).plot(kind='pie',
                                                              colors=colors,
                                                               autopct='%.2f%%')
plt.show()
# Out:
# 2    48.914729
# 3    27.737403
# 1    11.904070
# 4     8.100775
# 5     3.343023
# Name: income_cat, dtype: float64

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=123)

# %%
print((X_train['income_cat'].value_counts()/X_train.shape[0])*100)
plt.figure(dpi=100)
((X_train['income_cat'].value_counts()/X_train.shape[0])*100).plot(kind='pie',
                                                              colors=colors,
                                                               autopct='%.2f%%')
plt.show()
# Out:
# 2    49.055233
# 3    27.525436
# 1    11.833818
# 4     8.248547
# 5     3.336967
# Name: income_cat, dtype: float64

# %%
print((X_test['income_cat'].value_counts()/X_test.shape[0])*100)
plt.figure(dpi=100)
((X_test['income_cat'].value_counts()/X_test.shape[0])*100).plot(kind='pie',
                                                              colors=colors,
                                                               autopct='%.2f%%')
plt.show()
# Out:
# 2    48.352713
# 3    28.585271
# 1    12.185078
# 4     7.509690
# 5     3.367248
# Name: income_cat, dtype: float64

# %%
from sklearn.model_selection import StratifiedShuffleSplit

# %%
data2=housing.copy()
data2.dropna(inplace=True)

# %%
data2['income_cat']=pd.cut(data2['median_income'],bins=[0, 2, 4, 6 , 8,np.inf]
      , labels = [1,2,3,4,5]) #labels=['very low','low','avg','high','very high']

# %%
target1='median_house_value'

# %%
y1 = data2[target]
X1 = data2.drop(target,axis=1)

# %%
X1.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income ocean_proximity income_cat
# 0       322.0       126.0         8.3252        NEAR BAY          5
# 1      2401.0      1138.0         8.3014        NEAR BAY          5
# 2       496.0       177.0         7.2574        NEAR BAY          4
# 3       558.0       219.0         5.6431        NEAR BAY          3
# 4       565.0       259.0         3.8462        NEAR BAY          2

# %%
split=StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=123)

# %%
(X1['ocean_proximity'].value_counts()/X1.shape[0])*100
# Out:
# <1H OCEAN     44.212793
# INLAND        31.791709
# NEAR OCEAN    12.861547
# NEAR BAY      11.109480
# ISLAND         0.024470
# Name: ocean_proximity, dtype: float64

# %%
(train_idxs, test_idxs), = split.split(X1, X1['ocean_proximity'])

# %%
X1_train=X1.iloc[train_idxs]
X1_test=X1.iloc[test_idxs]

# %%
(X1_train['ocean_proximity'].value_counts()/X1_train.shape[0])*100
# Out:
# <1H OCEAN     44.212651
# INLAND        31.793711
# NEAR OCEAN    12.859415
# NEAR BAY      11.109752
# ISLAND         0.024471
# Name: ocean_proximity, dtype: float64

# %%
(X1_test['ocean_proximity'].value_counts()/X1_test.shape[0])*100
# Out:
# <1H OCEAN     44.213359
# INLAND        31.783704
# NEAR OCEAN    12.870076
# NEAR BAY      11.108392
# ISLAND         0.024468
# Name: ocean_proximity, dtype: float64

# %%
(train_idxs, test_idxs), = split.split(X1, X1['income_cat'])

# %%
X1_train=X1.iloc[train_idxs]
X1_test=X1.iloc[test_idxs]
y1_train=y1.iloc[train_idxs]
y1_test=y1.iloc[test_idxs]

# %%
def get_ratio(df, col):
    frac = (df[col].value_counts()/df.shape[0])*100
    print(frac)

# %%
print('Data Set')
get_ratio(X1, 'income_cat')
# Out:
# Data Set
# 2    48.896393
# 3    27.778593
# 1    11.887633
# 4     8.104537
# 5     3.332844
# Name: income_cat, dtype: float64

# %%
print("Training data")
get_ratio(X1_train, 'income_cat')
# Out:
# Training data
# 2    48.892695
# 3    27.780497
# 1    11.886700
# 4     8.105959
# 5     3.334149
# Name: income_cat, dtype: float64

# %%
print("Test Data")
get_ratio(X1_test, 'income_cat')
# Out:
# Test Data
# 2    48.911182
# 3    27.770981
# 1    11.891363
# 4     8.098850
# 5     3.327624
# Name: income_cat, dtype: float64

# %%
def stratified_sample(X1,y1,col, test_size=0.2, random_state=123):
    split = StratifiedShuffleSplit(n_splits=1, test_size=test_size,
                                  random_state=random_state)
    for train_idsx, test_idxs in split.split(X1, X1[col] ):
        X1_train=X1.iloc[train_idxs]
        X1_test=X1.iloc[test_idxs]
        y1_train=y1.iloc[train_idxs]
        y1_test=y1.iloc[test_idxs]
    return X1_train, X1_test, y1_train, y1_test

# %%
X1_train, X1_test, y1_train, y1_test=stratified_sample(X1,y1, 'income_cat')

# %%
X1_train.head()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 11085    -117.89     33.84                35.0       3315.0           744.0
# 17144    -122.19     37.45                18.0       1636.0           414.0
# 4345     -118.37     34.12                34.0       2821.0           399.0
# 12419    -116.22     33.72                28.0        826.0           258.0
# 20389    -118.90     34.19                26.0       1582.0           196.0
#
#        population  households  median_income ocean_proximity income_cat
# 11085      2425.0       687.0         3.5521       <1H OCEAN          2
# 17144       853.0       439.0         5.1032      NEAR OCEAN          3
# 4345        843.0       391.0        11.6150       <1H OCEAN          5
# 12419       979.0       245.0         1.7172          INLAND          1
# 20389       573.0       182.0        10.0595       <1H OCEAN          5

# %%
X1_test.head()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 12333    -116.48     33.94                10.0       3254.0           913.0
# 17401    -120.44     34.93                16.0       2098.0           558.0
# 7469     -118.20     33.93                38.0       1626.0           307.0
# 20459    -118.77     34.28                26.0       2873.0           480.0
# 19349    -123.01     38.67                33.0        914.0           147.0
#
#        population  households  median_income ocean_proximity income_cat
# 12333       923.0       486.0         1.8000          INLAND          1
# 17401      1252.0       492.0         2.1509       <1H OCEAN          2
# 7469       1280.0       295.0         3.5313       <1H OCEAN          2
# 20459      1915.0       475.0         5.3681       <1H OCEAN          3
# 19349       394.0       132.0         4.6875       <1H OCEAN          3

# %%
get_ratio(X1_train, 'income_cat')
# Out:
# 2    48.892695
# 3    27.780497
# 1    11.886700
# 4     8.105959
# 5     3.334149
# Name: income_cat, dtype: float64

# %%
get_ratio(X1_test, 'income_cat')
# Out:
# 2    48.911182
# 3    27.770981
# 1    11.891363
# 4     8.098850
# 5     3.327624
# Name: income_cat, dtype: float64

# %%
X1_train.shape
# Out:
# (16346, 10)

# %%
X1_test.shape
# Out:
# (4087, 10)

# %%
# Create copies of the DataFrames
X1_train_copy = X1_train.copy()
X1_test_copy = X1_test.copy()

# Drop 'income_cat' in the copies
X1_train_copy.drop('income_cat', axis=1, inplace=True)
X1_test_copy.drop('income_cat', axis=1, inplace=True)

# %%
X1_train.shape
# Out:
# (16346, 9)

# %%
X1_train.head()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 11085    -117.89     33.84                35.0       3315.0           744.0
# 17144    -122.19     37.45                18.0       1636.0           414.0
# 4345     -118.37     34.12                34.0       2821.0           399.0
# 12419    -116.22     33.72                28.0        826.0           258.0
# 20389    -118.90     34.19                26.0       1582.0           196.0
#
#        population  households  median_income ocean_proximity income_cat
# 11085      2425.0       687.0         3.5521       <1H OCEAN          2
# 17144       853.0       439.0         5.1032      NEAR OCEAN          3
# 4345        843.0       391.0        11.6150       <1H OCEAN          5
# 12419       979.0       245.0         1.7172          INLAND          1
# 20389       573.0       182.0        10.0595       <1H OCEAN          5

# %%
X1_train.drop('ocean_proximity',axis=1,inplace=True)
# Out:
# /var/folders/x_/h473qyjj2rs9gv37gmr9mwd40000gn/T/ipykernel_91092/1018094992.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X1_train.drop('ocean_proximity',axis=1,inplace=True)

# %%
X1_test.drop('ocean_proximity',axis=1,inplace=True)
# Out:
# /var/folders/x_/h473qyjj2rs9gv37gmr9mwd40000gn/T/ipykernel_91092/2683387305.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X1_test.drop('ocean_proximity',axis=1,inplace=True)

# %%
X1_train
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 11085    -117.89     33.84                35.0       3315.0           744.0
# 17144    -122.19     37.45                18.0       1636.0           414.0
# 4345     -118.37     34.12                34.0       2821.0           399.0
# 12419    -116.22     33.72                28.0        826.0           258.0
# 20389    -118.90     34.19                26.0       1582.0           196.0
# ...          ...       ...                 ...          ...             ...
# 16016    -122.46     37.73                52.0       3547.0           506.0
# 12955    -121.30     38.70                18.0       7334.0          1332.0
# 15285    -117.33     33.16                29.0       3559.0           552.0
# 16670    -120.52     35.24                 5.0       4413.0           804.0
# 1212     -120.55     38.07                27.0       1199.0           224.0
#
#        population  households  median_income income_cat
# ...

# %%
from sklearn.linear_model import LinearRegression, SGDRegressor
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor

# %%
models = [
    ('linear regression', LinearRegression()),
    ('sgd', SGDRegressor()),
    ('Tree', RandomForestRegressor()),
    ('KNN', KNeighborsRegressor())
]

# %%
# from sklearn.metrics import mean_squared_error, r2_score


# def rmse(y, y_hat):
#     return np.sqrt(mean_squared_error(y,y_hat))

# %%
# def model_report(models):    
#     for name , model in models:
#         print(f"Model {name}".center(80))
#         print()
#         model.fit(X1_train,y1_train)
#         y_hat = model.predict(X1_train)
#         print(f"Training Error of {name:^20} Model:{rmse(y1_train,y_hat):.2f}")
#         print(f"Training Accuracy of {name:^20} Model:{r2_score(y1_train,y_hat)*100:.2f}")
#         y_hat = model.predict(X1_test)
#         print('--'*40)
#         print(f"Test Error of {name:^20} Model: {rmse(y1_test,y_hat):.2f}")
#         print(f"Training Accuracy of {name:^20} Model:{r2_score(y1_train,y_hat)*100:.2f}")
        
#         print('\n\n')
#         print('__'*40)
#         print('\n\n')

# %%
print(f"X1_train shape: {X1_train.shape}")
print(f"y1_train shape: {y1_train.shape}")
print(f"X1_test shape: {X1_test.shape}")
print(f"y1_test shape: {y1_test.shape}")
# Out:
# X1_train shape: (16346, 9)
# y1_train shape: (16346,)
# X1_test shape: (4087, 9)
# y1_test shape: (4087,)

# %%
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.linear_model import LinearRegression, SGDRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor


def model_report(models, X1_train, y1_train, X1_test, y1_test):
    for name, model in models:
        print(f"Model {name}".center(80))
        print()
        
        # Fit the model on training data
        model.fit(X1_train, y1_train)
        
        # Predict on training data
        y_hat_train = model.predict(X1_train)
        
        # Compute metrics for training data
        train_rmse = mean_squared_error(y1_train, y_hat_train, squared=False)
        train_r2 = r2_score(y1_train, y_hat_train)
        
        print(f"Training Error of {name:^20} Model: {train_rmse:.2f}")
        print(f"Training R^2 Score of {name:^20} Model: {train_r2*100:.2f}")
        
        print('--' * 40)
        
        # Predict on test data
        y_hat_test = model.predict(X1_test)
        
        # Compute metrics for test data
        test_rmse = mean_squared_error(y1_test, y_hat_test, squared=False)
        test_r2 = r2_score(y1_test, y_hat_test)
        
        print(f"Test Error of {name:^20} Model: {test_rmse:.2f}")
        print(f"Test R^2 Score of {name:^20} Model: {test_r2*100:.2f}")
        
        print('\n\n')
        print('__' * 40)
        print('\n\n')

# Example usage:
model_report(models, X1_train, y1_train, X1_test, y1_test)
# Out:
#                             Model linear regression
#
# Training Error of  linear regression   Model: 69095.70
# Training R^2 Score of  linear regression   Model: 63.92
# --------------------------------------------------------------------------------
# Test Error of  linear regression   Model: 70263.28
# Test R^2 Score of  linear regression   Model: 63.94
#
#
#
# ________________________________________________________________________________
#
#
#
#                                    Model sgd
#
# Training Error of         sgd          Model: 1348267532390983.25
# Training R^2 Score of         sgd          Model: -13739140922066759319552.00
# --------------------------------------------------------------------------------
# Test Error of         sgd          Model: 1325552958313138.75
# Test R^2 Score of         sgd          Model: -12833368094464599392256.00
#
#
#
# ________________________________________________________________________________
#
#
#
# ...

# %%
housing.isna().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %%
# Create copies of the DataFrames
X1_train_copy = X1_train.copy()
X1_test_copy = X1_test.copy()
y1_train_copy = y1_train.copy()
y1_test_copy = y1_test.copy()

# Drop NaN values in the copies
X1_train_copy.dropna(inplace=True)
X1_test_copy.dropna(inplace=True)
y1_train_copy.dropna(inplace=True)
y1_test_copy.dropna(inplace=True)

# %%
model_report(models, X1_train_copy, y1_train_copy, X1_test_copy, y1_test_copy)
# Out:
#                             Model linear regression
#
# Training Error of  linear regression   Model: 69095.70
# Training R^2 Score of  linear regression   Model: 63.92
# --------------------------------------------------------------------------------
# Test Error of  linear regression   Model: 70263.28
# Test R^2 Score of  linear regression   Model: 63.94
#
#
#
# ________________________________________________________________________________
#
#
#
#                                    Model sgd
#
# Training Error of         sgd          Model: 3788382664944514.00
# Training R^2 Score of         sgd          Model: -108471365327156106231808.00
# --------------------------------------------------------------------------------
# Test Error of         sgd          Model: 3727968957461449.50
# Test R^2 Score of         sgd          Model: -101505846957565351559168.00
#
#
#
# ________________________________________________________________________________
#
#
#
# ...
